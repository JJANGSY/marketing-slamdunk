# %%
from konlpy.tag import Okt
from collections import Counter

# %%
# 크롤링 결과로 저장된 csv 파일을 불러낸 후, 가장 많이 언급된 상위 500개 명사+형용사를 추출함.

f = open(r'C:\Users\jjang\KDT\슬램덩크 마케팅\0221 크롤링 2\01 수집텍스트140.txt', encoding='utf8')
blog_txt = f.read()

okt = Okt()
line = []

line = okt.pos(blog_txt)
n_adj = []
for word, tag in line:
    if tag in ["Noun", "Adjective"]:
        n_adj.append(word)

counts = Counter(n_adj)
tags = counts.most_common(500)

# %%
# 상위 230개 단어를 tags_230 변수에 할당함.

tags_230 = [('진짜', 273), ('슬램덩크', 257), ('영화', 256), ('생각', 195), ('친구', 103), ('맛', 94), ('오늘', 91), ('농구', 85),  ('요즘', 79), ('일본', 78), ('사실', 73), ('이번', 71), ('마음', 70), ('사랑', 68), ('밥', 65), ('엄마', 62), ('다음', 60), ('처음', 60),  ('저녁', 59), ('강백호', 55), ('다른', 55), ('만화', 54), ('카페', 53), ('좋은', 53), ('느낌', 52),('혼자', 52), ('기분', 50), ('역시', 50), ('책', 47), ('얼굴', 46), ('정대만', 46), ('기억', 45), ('이야기', 44), ('만화책', 43), ('마지막', 43), ('서태웅', 43), ('술', 42), ('한번', 42), ('블로그', 41), ('좋아하는', 40), ('고민', 40), ('언니', 40), ('캐릭터', 40), ('노래', 39), ('이유', 39), ('구매', 39), ('위해', 39), ('영화관', 39), ('주문', 39), ('송태섭', 38), ('하루', 38), ('별로', 36), ('내용', 36), ('장면', 35), ('머리', 35), ('작품', 35), ('이건', 35), ('없어서', 34), ('동생', 34), ('오빠', 34), ('가장', 34), ('출근', 34), ('최고', 33), ('봄', 33), ('아침', 33), ('미친', 33), ('경기', 33), ('음', 33), ('아빠', 33), ('얘기', 32), ('추천', 32), ('이름', 32), ('개인', 32), ('버스', 32), ('어떻게', 32), ('우동', 32), ('애니', 31), ('굿', 31), ('누가', 31), ('돈', 31), ('자신', 31), ('한국', 31), ('애니메이션', 31),  ('추가', 31), ('퍼스트', 30), ('도착', 30), ('빵', 30), ('제일', 29), ('준비', 29), ('눈물', 29), ('첫', 29), ('여행', 29), ('팝콘', 29), ('카메라', 28), ('귀여운', 28), ('그림', 28), ('새로운', 28), ('걱정', 27), ('음식', 27), ('점심', 27)]

# %%
# 상위 100개 단어를 tags_100 변수에 할당함.

tags_100 = [('진짜', 273), ('슬램덩크', 257), ('영화', 256), ('생각', 195), ('친구', 103), ('맛', 94), ('오늘', 91), ('농구', 85),  ('요즘', 79), ('일본', 78), ('사실', 73), ('이번', 71), ('마음', 70), ('사랑', 68), ('밥', 65), ('엄마', 62), ('다음', 60), ('처음', 60),  ('저녁', 59), ('강백호', 55), ('다른', 55), ('만화', 54), ('카페', 53), ('좋은', 53), ('느낌', 52),('혼자', 52), ('기분', 50), ('역시', 50), ('책', 47), ('얼굴', 46), ('정대만', 46), ('기억', 45), ('이야기', 44), ('만화책', 43), ('마지막', 43), ('서태웅', 43), ('술', 42), ('한번', 42), ('블로그', 41), ('좋아하는', 40), ('고민', 40), ('언니', 40), ('캐릭터', 40), ('노래', 39), ('이유', 39), ('구매', 39), ('위해', 39), ('영화관', 39), ('주문', 39), ('송태섭', 38), ('하루', 38), ('별로', 36), ('내용', 36), ('장면', 35), ('머리', 35), ('작품', 35), ('이건', 35), ('없어서', 34), ('동생', 34), ('오빠', 34), ('가장', 34), ('출근', 34), ('최고', 33), ('봄', 33), ('아침', 33), ('미친', 33), ('경기', 33), ('음', 33), ('아빠', 33), ('얘기', 32), ('추천', 32), ('이름', 32), ('개인', 32), ('버스', 32), ('어떻게', 32), ('우동', 32), ('애니', 31), ('굿', 31), ('누가', 31), ('돈', 31), ('자신', 31), ('한국', 31), ('애니메이션', 31),  ('추가', 31), ('퍼스트', 30), ('도착', 30), ('빵', 30), ('제일', 29), ('준비', 29), ('눈물', 29), ('첫', 29), ('여행', 29), ('팝콘', 29), ('카메라', 28), ('귀여운', 28), ('그림', 28), ('새로운', 28), ('걱정', 27), ('음식', 27), ('점심', 27), ('후기', 27), ('바지', 27), ('커피', 27), ('대충', 26), ('손', 26), ('관람', 26), ('선수', 25), ('분위기', 25), ('호텔', 25), ('구경', 25), ('남자', 25), ('가격', 25), ('모습', 25), ('감동', 24),('생일', 24), ('타임', 24),('문제', 24), ('예매', 24), ('북산', 24), ('자주', 24), ('중간', 24), ('키', 23), ('학교', 23), ('선물', 23), ('무대', 23), ('서치', 23), ('재미', 23), ('먹음', 22), ('자막', 22), ('고양이', 22), ('마무리', 22), ('딸기', 22), ('바다', 22), ('최근', 22), ('운동', 22), ('방문', 22), ('좋았다', 22), ('주인공', 22), ('유튜브', 21), ('스토리', 21), ('겨울', 21), ('영상', 21), ('여전히', 21), ('좋아', 21), ('티비', 21), ('신발', 20), ('폰', 20), ('데이트', 20), ('퇴근', 20), ('오히려', 20), ('연출', 20), ('메뉴', 20), ('날씨', 20), ('열차', 20), ('한국인', 20), ('공부', 19), ('새벽', 19), ('응원', 19), ('강아지', 19), ('최애', 19), ('백호', 19), ('기대', 19), ('꿈', 19), ('맛집', 19), ('감독', 19), ('소스', 19), ('맛있다', 19), ('라면', 19), ('오타쿠', 19), ('감성', 19), ('당황', 19), ('초밥', 19),('인생', 18), ('입장', 18), ('게임', 18), ('좋아서', 18), ('벌써', 18), ('대사', 18), ('원작', 18),('순간', 18), ('스포츠', 18), ('그때', 18), ('도쿄', 18), ('검색어', 18), ('추억', 17), ('의미', 17), ('제대로', 17), ('바람', 17), ('내일', 17), ('자꾸', 17), ('농놀', 17),('회사', 17), ('채치수', 17), ('전시', 17), ('촬영', 17), ('맛있는', 17), ('평소', 16), ('등장', 16), ('검색', 16), ('옷', 16), ('작가', 16), ('옛날', 16), ('슬덩', 16), ('집중', 16), ('성공', 16), ('패스', 16), ('경험', 16), ('덕분', 16),  ('매일', 16), ('상품', 16), ('더빙', 15), ('파티', 15), ('포기', 15), ('막콘', 15), ('귀여워', 15), ('솔직히', 15), ('티켓', 15), ('사용', 15), ('이용', 15), ('웨이팅', 15), ('예전', 15), ('시대', 15), ('상영', 15), ('선배', 15), ('할머니', 15), ('가족', 15), ('인기', 15), ('데뷔', 15), ('건강', 15), ('테이블', 15)]

# %%
from wordcloud import WordCloud

# %%
# 워드 클라우드

font = r"C:\Users\jjang\KDT\슬램덩크 마케팅\malgun.ttf"
word_cloud = WordCloud(font_path = font, width=3000, height=3000, max_font_size=700, background_color = "white", colormap = "Dark2").generate_from_frequencies(dict(tags_230)) # 100개 단어 클라우드 할 때에는 tags_100 변수 사용할 것.
import matplotlib.pyplot as plt
plt.figure(figsize = (15,12))
plt.imshow(word_cloud)
plt.axis("off")
